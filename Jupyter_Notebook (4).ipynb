# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Hilary Akatwijuka**
# <br>Data science Engineer<br>

# %% [markdown]
# <br>*I am interested in data science because*<br>
# <br>*Being in demand, it has given rise to a large number of career opportunities in its various fields*<br>
# <br>*As Data Scientist continues being the sexiest job and the salaries for this position are also grand. According to a Dice Salary Survey, the annual average salary of a Data Scientist $106,000 per year*<br>

# %% [markdown]
# ### My code in cell 5 should print a Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# - This is a bullet
# * This is a bullet
#    - this is a sub bullet
#
#    * This is a sub bullet
#
#
#
#    1. Line Number one
#
#    2. Line Number Two
#
#       A. Sub Line Number one
#
#       B. sub line number Two
#
#
#       ---
#
#       Horizontal Rule
#
#       ---
#
#       #### Tables
#
# | --- | --- | --- |
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |
#
# ##### CNN Hyper link
#
#
# [This is a Link to CNN Web site](https://edition.cnn.com/)
#
#
# ###### Cat Image
#
#
#
#
#
#
#
#
#
#
#
# ![Screenshot 2022-10-04 144252.png](attachment:b8dd1116-9762-416d-aa49-6a06a77270f9.png)
#
# ###### Strike though
#
#
#
#
#
#
#
#
#
#  In a few moments he was barefoot, ~~his stockings folded in his pockets~~
#
#   ###### blocked Quotes
#
#   >In a few moments he was barefoot his stockings folded in his pockets
#
#   ##### Code high lighting
#
#   ` Python
#     my list = ['Data science Boy', 1, True]
#     `
#
#    ###### syntax Highlighting
#
#
#    ```Python
#     my list = ['Data science Boy', 1, True]
#     ```
